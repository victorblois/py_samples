# %% [markdown]
# # Título
# ---
#
# #### Usar #
#
# # Título nível 1
# ## Título nível 2
# ### Título nível 3
# #### Título nível 4
# ##### Título nível 5
# ###### Título nível 6
#
#
# # Parágrafos e quebras de linha
# ---
# #### Paragráfos: Escrever pulando uma linha
#
# Este é um parágrafo.
#
# Este é outro parágrafo.
#
#
# #### Quebra de linha: dois espaços em branco
#
# Esta linha.
# Outra linha.
#
# Esta linha.
# Outra linha.
#
#
# # Negrito
# ---
# #### Usamos * ou _
#
# _Isto_ é legal.
#
#
# #### Negrito forte ** ou __
#
# __Isto__ é legal.
#
#
# # Link
# ---
# #### Usamos []() ou <>
#
# [Meu GIT](https://github.com/victorblois)
# <https://www.google.com.br>
# <vlmblois@yahoo.com.br>
#
#
# # Listas
# ---
# #### Usamos \*, \+ ou \-
#
# + Victor
# + João
# + Blois
#
# #### Listas ordenadas: Número em sequência ponto, Subitens começa com 3 espaços
#
# 1. Victor
#    1.1 Luis
# 2. João
# 3. Blois
#
# #### Listas de tarefas
#
# - [ ] Fazer isto
# - [ ] Depois Isto
# - [x] Finalizar
#
# #  Imagem
# ---
# #### Usar \!\[\]\(\)
#
# ![Victor Blois](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcRo3UU7LXEOH7ZAFL_BxqDhtlDi-r4N8tiX5u0PgaoFMfW5_FpA&usqp=CAU)
#
#
# # Tabela
# ---
# #### Usar \---\|---\|----
#
# Num|Nome|Data
# ---|---|---
# 1|Victor|19-11-2010
# 2|Blois|19-12-2010
# 3|Luis|19-12-2010
# 4|Gugs|19-12-2010
#
# # Blocos de programas
# ---
# #### Usar   \`    \` ou \```   \``` (crases)
#
# uma variável  `x=23`
#
# ```
# num = 3
# x=17*2
# ```
